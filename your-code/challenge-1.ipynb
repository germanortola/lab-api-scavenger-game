# %%
import json
import requests

# %% [markdown]
# Only if you're using your environmental variable eith the `.env` file, import/install the following modules. Otherwise it is not necessary:
#
# https://pypi.org/project/python-dotenv/

# %%
import os
from dotenv import load_dotenv

# %%
#pip install python-dotenv

# %%
load_dotenv()
# Out:
# False

# %%
github = os.getenv("token")

# %% [markdown]
# # Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/datamad1020-rev, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
#
# 3. Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %% [markdown]
# **HINT:**: Create a list with every **language_url** you find in every fork

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
token = os.getenv("token")
user = os.getenv("user")

# %%
url_forks = "https://api.github.com/repos/Ironhack-data-bcn-january-2023/lab-api-scavenger-game/forks"

json_lab = requests.get(url_forks).json()

# %%
json_lab
# Out:
# [{'id': 596590598,
#   'node_id': 'R_kgDOI49ABg',
#   'name': 'lab-api-scavenger-game',
#   'full_name': 'castrokike/lab-api-scavenger-game',
#   'private': False,
#   'owner': {'login': 'castrokike',
#    'id': 62567171,
#    'node_id': 'MDQ6VXNlcjYyNTY3MTcx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62567171?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/castrokike',
#    'html_url': 'https://github.com/castrokike',
#    'followers_url': 'https://api.github.com/users/castrokike/followers',
#    'following_url': 'https://api.github.com/users/castrokike/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/castrokike/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/castrokike/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/castrokike/subscriptions',
#    'organizations_url': 'https://api.github.com/users/castrokike/orgs',
# ...

# %%
lang_url_list=[]

def lang_url(json_lab):
    
    for lang_key in json_lab:
        for x, y in lang_key.items():
            if x == "languages_url":
                lang_url_list.append(y)
    return lang_url_list

# %%
lang_url(json_lab)
# Out:
# ['https://api.github.com/repos/castrokike/lab-api-scavenger-game/languages',
#  'https://api.github.com/repos/TomBanner/lab-api-scavenger-game/languages',
#  'https://api.github.com/repos/David231723/lab-api-scavenger-game/languages',
#  'https://api.github.com/repos/Detest9067/lab-api-scavenger-game/languages',
#  'https://api.github.com/repos/danidimarti/lab-api-scavenger-game/languages',
#  'https://api.github.com/repos/santiago20233/lab-api-scavenger-game/languages',
#  'https://api.github.com/repos/gerardrius/lab-api-scavenger-game/languages',
#  'https://api.github.com/repos/imalanz/lab-api-scavenger-game/languages',
#  'https://api.github.com/repos/nb3110/lab-api-scavenger-game-blasi/languages',
#  'https://api.github.com/repos/victorjrp92/lab-api-scavenger-game/languages',
#  'https://api.github.com/repos/TimKuijten/lab-api-scavenger-game/languages',
#  'https://api.github.com/repos/germanortola/lab-api-scavenger-game/languages',
# ...

# %%
def lang_url_set(lang_url_list):
    lang_url_result=[]
    for a in lang_url_list:
        temp_list=list(requests.get(a).json())
    for d in temp_list:
        for e, f in d.items():
            lang_url_result.append(e)
    return set(lang_url_result)

# %%
lang_url_set(lang_url_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\germa\github\lab-api-scavenger-game\your-code\challenge-1.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/germa/github/lab-api-scavenger-game/your-code/challenge-1.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> lang_url_set(lang_url_list)
#
# c:\Users\germa\github\lab-api-scavenger-game\your-code\challenge-1.ipynb Cell 16 in lang_url_set(lang_url_list)
#       <a href='vscode-notebook-cell:/c%3A/Users/germa/github/lab-api-scavenger-game/your-code/challenge-1.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a>     temp_list=list(requests.get(a).json())
#       <a href='vscode-notebook-cell:/c%3A/Users/germa/github/lab-api-scavenger-game/your-code/challenge-1.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> for d in temp_list:
# ...
